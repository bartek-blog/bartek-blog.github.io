# %% [markdown]
# Data from <https://www.kaggle.com/ronitf/heart-disease-uci>
#
# ```
# pip install pymongo
# ```
#
# Run mongodb:
# ```
# mongod
# ```

# %%
import pandas as pd

heart_df = pd.read_csv("data/heart.csv")
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## To json

# %%
heart_json = heart_df.to_json(orient="records")

# %% [markdown]
# ## To dict

# %%
import json
heart_dict = json.loads(heart_json)

# %% [markdown]
# ## Database

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.heart_uci
patients = db.patients

# %%
patients.insert_many(heart_dict)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-10-d0052a5485dc> in <module>
# ----> 1 patients.insert_many(heart_dict)
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     751         blk = _Bulk(self, ordered, bypass_document_validation)
#     752         blk.ops = [doc for doc in gen()]
# --> 753         blk.execute(write_concern, session=session)
#     754         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     755
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     511                 self.execute_no_results(sock_info, generator)
#     512         else:
# --> 513             return self.execute_command(generator, write_concern, session)
#     514
#     515
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     334
#     335         client = self.collection.database.client
# --> 336         with client._tmp_session(session) as s:
#     337             client._retry_with_session(
#     338                 self.is_retryable, retryable_bulk, s, self)
#
# ~/.pyenv/versions/3.6.8/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1569             return
#    1570
# -> 1571         s = self._ensure_session(session)
#    1572         if s and close:
#    1573             with s:
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1556             # Don't make implicit sessions causally consistent. Applications
#    1557             # should always opt-in.
# -> 1558             return self.__start_session(True, causal_consistency=False)
#    1559         except (ConfigurationError, InvalidOperation):
#    1560             # Sessions not supported, or multiple users authenticated.
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1509
#    1510         # Raises ConfigurationError if sessions are not supported.
# -> 1511         server_session = self._get_server_session()
#    1512         opts = client_session.SessionOptions(**kwargs)
#    1513         return client_session.ClientSession(
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1542     def _get_server_session(self):
#    1543         """Internal: start or resume a _ServerSession."""
# -> 1544         return self._topology.get_server_session()
#    1545
#    1546     def _return_server_session(self, server_session, lock):
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/topology.py in get_server_session(self)
#     425                             any_server_selector,
#     426                             self._settings.server_selection_timeout,
# --> 427                             None)
#     428                 elif not self._description.readable_servers:
#     429                     self._select_servers_loop(
#
# ~/.virtualenvs/py3.6-reflections/lib/python3.6/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     197             if timeout == 0 or now > end_time:
#     198                 raise ServerSelectionTimeoutError(
# --> 199                     self._error_message(selector))
#     200
#     201             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 61] Connection refused

# %%
patients.find_one({"age": 41})

# %%
for patient in patients.find({"age": 41}):
    print(f"{patient['chol']}: {patient['target']}")
# Out:
# 204: 1
# 198: 1
# 203: 1
# 250: 1
# 214: 1
# 268: 1
# 235: 1
# 306: 1
# 157: 1
# 172: 0

# %%
all_patients = patients.find({})
patients_df = pd.DataFrame(list(all_patients))
patients_df.head()
# Out:
#                         _id  age  ca  chol  cp  exang  fbs  oldpeak  restecg  \
# 0  5c87dd87e4146a3fbd307ccb   63   0   233   3      0    1      2.3        0
# 1  5c87dd87e4146a3fbd307ccc   37   0   250   2      0    0      3.5        1
# 2  5c87dd87e4146a3fbd307ccd   41   0   204   1      0    0      1.4        0
# 3  5c87dd87e4146a3fbd307cce   56   0   236   1      0    0      0.8        1
# 4  5c87dd87e4146a3fbd307ccf   57   0   354   0      1    0      0.6        1
#
#    sex  slope  target  thal  thalach  trestbps
# 0    1      0       1     1      150       145
# 1    1      0       1     2      187       130
# 2    0      2       1     2      172       130
# 3    1      2       1     2      178       120
# 4    0      2       1     2      163       120
